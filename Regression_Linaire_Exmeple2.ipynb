# %% [markdown]
# <a href="https://colab.research.google.com/github/Takouabelwafa/Machine_Learning/blob/main/Regression_Linaire_Exmeple2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step1 :  import librairy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from google.colab import drive
# monter le drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data=pd.read_csv('/content/drive/MyDrive/formation IA/Real estate.csv')

# %%
y=data['Y house price of unit area']
x=data.drop('Y house price of unit area',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
print("R2:",r2)
# Out:
# MAE: 5.418035098629173
# MSE: 54.60196067337693
# RMSE: 54.60196067337693
# R2: 0.6745228670350882

# %% [markdown]
# ### Interprétation
#
# **MAE**  Les prédictions s'écartent au moyenne  de **5.42 unités** du vrai prix.
#  **MSE** Moyenne des erreurs au carré ; plus grande sensibilité aux grosses erreurs.
#  **RMSE**   Cela montre qu'il y a quelques écarts plus importants.
# **R²**  Le modèle **explique environ 67 % de la variance** des prix.

# %%
import matplotlib.pyplot as plt

# Tracer les valeurs réelles vs les prédictions
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # ligne y=x
plt.xlabel("Prix réel")
plt.ylabel("Prix prédit")
plt.title("Prix réel vs Prix prédit")
plt.show()
