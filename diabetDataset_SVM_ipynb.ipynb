# %% [markdown]
# <a href="https://colab.research.google.com/github/Takouabelwafa/Machine_Learning/blob/main/diabetDataset_SVM_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Séance précédente (Samedi 11/10/2025) :**
#
#
#
# *   Application de la régression linéaire et de la régression logistique sur le dataset diabet.csv.
# lien d'accée:
#   https://colab.research.google.com/drive/1FpbjITYsX-fqf5C9JM2MVXatNMvWgMnq?usp=sharing
#
#
#
#
# ## **Nouvelle mission :**
#
#
#
# *   Appliquer le modèle SVM linéaire et Ridge Regression (RBR) sur le dataset diabet.csv.
#
# *   Comparer les accuracies obtenues par chaque modèle.

# %%
#impoting required librairies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Acess the drive from Colab , for accessing the file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df=pd.read_csv('/content/drive/MyDrive/formation IA/diabetes.csv')

# %%
x = df.drop("Outcome", axis=1)
y = df["Outcome"]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Standardize the numerical features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = svm.SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

# Matrice de confusion
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Rapport complet (precision, recall, f1-score)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7532467532467533
# Confusion Matrix:
#  [[80 19]
#  [19 36]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        99
#            1       0.65      0.65      0.65        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.75      0.75      0.75       154

# %%
model_rbf= svm.SVC(kernel='rbf', C=1.0, gamma='scale')
#SVM avec noyau RBF (Radial Basis Function)
model_rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Prédictions
y_pred_rbf = model_rbf.predict(X_test)

# Accuracy
acc_rbf = accuracy_score(y_test, y_pred_rbf)
print("Accuracy SVM RBF:", acc_rbf)

# Matrice de confusion
cm_rbf = confusion_matrix(y_test, y_pred_rbf)
print("Confusion Matrix:\n", cm_rbf)

# Classification report
print(classification_report(y_test, y_pred_rbf))
# Out:
# Accuracy SVM RBF: 0.7662337662337663
# Confusion Matrix:
#  [[87 12]
#  [24 31]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        99
#            1       0.72      0.56      0.63        55
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.72      0.73       154
# weighted avg       0.76      0.77      0.76       154

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.heatmap(cm_rbf, annot=True, fmt="d", cmap="Oranges", xticklabels=[0,1], yticklabels=[0,1])
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.title("Matrice de Confusion - SVM RBF")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
